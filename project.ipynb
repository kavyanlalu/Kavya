# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("datal.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# #  changing the data of that particular column with any random numbers between 150 and 180

# %%
df['Height'].replace('06-Feb', 161, inplace=True)
df
df.loc[df['Height'] == '06-Jun'	, 'Height'] = 156
df
df['Height'].replace('06-Jan', 169, inplace=True)
df
df['Height'].replace('06-Apr', 163, inplace=True)
df
df['Height'].replace('06-Mar', 164, inplace=True)
df
df['Height'].replace('06-May', 166, inplace=True)
df
df['Height'].replace('06-Jul', 169, inplace=True)
df
df['Height'].replace('06-Aug', 172, inplace=True)
df
df['Height'].replace('06-Sep', 162, inplace=True)
df
df['Height'].replace('06-Oct', 177, inplace=True)
df
df['Height'].replace('06-Nov', 168, inplace=True)
df
df['Height'].replace('06-Dec', 170, inplace=True)
df
df['Height'].replace('07-Jan', 179, inplace=True)
df
df['Height'].replace('07-Feb', 156, inplace=True)
df
df['Height'].replace('07-Mar', 155, inplace=True)
df
df['Height'].replace('7-0', 158, inplace=True)
df
df['Height'].replace('6-0', 174, inplace=True)
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    180     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    156     235
# 2     John Holland  Boston Celtics      30       SG   27    162     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    162     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29    162     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26    164     203
# 454      Raul Neto       Utah Jazz      25       PG   24    162     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    155     256
# 456    Jeff Withey       Utah Jazz      24        C   26    158     231
# 457       Priyanka       Utah Jazz      34        C   25    155     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # OR

# %%
df['Height'] = np.random.randint(150, 181, size=len(data))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     153     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     152     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     173     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     160     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     177     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
s=df['Team'].value_counts()
s
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
#percentage = (s / 458) * 100
percentage = (s / len(df) )* 100
percentage
h=pd.DataFrame({'Team':s.index,'Percentage':percentage.values})
h
# Out:
#                       Team  Percentage
# 0     New Orleans Pelicans    4.148472
# 1        Memphis Grizzlies    3.930131
# 2                Utah Jazz    3.493450
# 3          New York Knicks    3.493450
# 4          Milwaukee Bucks    3.493450
# 5            Brooklyn Nets    3.275109
# 6   Portland Trail Blazers    3.275109
# 7    Oklahoma City Thunder    3.275109
# 8           Denver Nuggets    3.275109
# 9       Washington Wizards    3.275109
# 10              Miami Heat    3.275109
# 11       Charlotte Hornets    3.275109
# 12           Atlanta Hawks    3.275109
# 13       San Antonio Spurs    3.275109
# 14         Houston Rockets    3.275109
# 15          Boston Celtics    3.275109
# 16          Indiana Pacers    3.275109
# 17         Detroit Pistons    3.275109
# 18     Cleveland Cavaliers    3.275109
# 19           Chicago Bulls    3.275109
# 20        Sacramento Kings    3.275109
# 21            Phoenix Suns    3.275109
# 22      Los Angeles Lakers    3.275109
# ...

# %% [markdown]
# # Segregate the employees w.r.t different positions.

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# # Find from which age group most of the employees belong to.

# %%
k=df.Age.value_counts()
k
j=pd.DataFrame({'Age':s.index,'Number of Employees':s.values})
j
# Out:
#     Age  Number of Employees
# 0    24                   47
# 1    25                   46
# 2    27                   41
# 3    23                   41
# 4    26                   36
# 5    28                   31
# 6    30                   31
# 7    29                   28
# 8    22                   26
# 9    31                   22
# 10   20                   19
# 11   21                   19
# 12   33                   14
# 13   32                   13
# 14   34                   10
# 15   36                   10
# 16   35                    9
# 17   37                    4
# 18   38                    4
# 19   40                    3
# 20   39                    2
# 21   19                    2

# %% [markdown]
# # Find out under which team and position, spending in terms of salary is high.

# %%
#x=df.groupby(['Team','Position'])['Salary'].sum()
#x
#df.Salary.max()
x=df.groupby(['Team','Position'])['Salary'].sum().reset_index()
y=x['Salary'].idxmax(axis=0)
z=x.loc[y,'Team']
w=x.loc[y,'Position']
print(z)
print(w)
# Out:
# Los Angeles Lakers
# SF

# %% [markdown]
# # Find if there is any correlation between age and salary , represent it visually.

# %%
a=df.dropna(subset=['Salary'])
a.loc[:,'Salary']=a['Salary'].astype(float)
plt.scatter(a['Age'],a['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation')
plt.show()
